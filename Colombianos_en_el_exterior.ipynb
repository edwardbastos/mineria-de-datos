# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/edwardbastos/mineria-de-datos/main/Colombianos_registrados_en_el_exterior.csv"
df = pd.read_csv (url)

# %%
df
# Out:
#                País Código ISO país   Oficina de registro    Grupo edad  \
# 0         ARGENTINA             ARG       C. BUENOS AIRES        ADULTO
# 1           BELGICA             BEL           C. BRUSELAS        ADULTO
# 2         VENEZUELA             VEN   C. SAN FNDO ATABAPO        ADULTO
# 3             SUIZA             CHE              C. BERNA        ADULTO
# 4            ESPAÑA             ESP          C. BARCELONA        ADULTO
# ...             ...             ...                   ...           ...
# 229534       CANADA             CAN           C. MONTREAL        ADULTO
# 229535    VENEZUELA             VEN         C. MERIDA VEN        ADULTO
# 229536  REINO UNIDO             GBR            C. LONDRES        ADULTO
# 229537       ESPAÑA             ESP  C. PALMA DE MALLORCA        ADULTO
# 229538       MEXICO             MEX             C. MEXICO  ADULTO JOVEN
#
#         Edad (años)                             Área Conocimiento  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229539 entries, 0 to 229538
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   País                   229539 non-null  object
#  1   Código ISO país        229539 non-null  object
#  2   Oficina de registro    229539 non-null  object
#  3   Grupo edad             229539 non-null  object
#  4   Edad (años)            229539 non-null  int64
#  5   Área Conocimiento      229539 non-null  object
#  6   Sub Area Conocimiento  229539 non-null  object
#  7   Nivel Académico        229539 non-null  object
#  8   Estado civil           229539 non-null  object
#  9   Género                 229539 non-null  object
#  10  Etnia de la persona    229539 non-null  object
#  11  Estatura (CM)          229539 non-null  int64
#  12  Localización           229539 non-null  object
#  13  Cantidad de personas   229539 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['País', 'Código ISO país', 'Oficina de registro', 'Grupo edad',
#        'Edad (años)', 'Área Conocimiento', 'Sub Area Conocimiento',
#        'Nivel Académico', 'Estado civil', 'Género', 'Etnia de la persona',
#        'Estatura (CM)', 'Localización', 'Cantidad de personas'],
#       dtype='object')

# %%
df.dtypes
# Out:
# País                     object
# Código ISO país          object
# Oficina de registro      object
# Grupo edad               object
# Edad (años)               int64
# Área Conocimiento        object
# Sub Area Conocimiento    object
# Nivel Académico          object
# Estado civil             object
# Género                   object
# Etnia de la persona      object
# Estatura (CM)             int64
# Localización             object
# Cantidad de personas      int64
# dtype: object

# %%
df.drop(columns = ['Oficina de registro', 'Sub Area Conocimiento', 'Etnia de la persona', 'Estatura (CM)', 'Localización'])
# Out:
#                País Código ISO país    Grupo edad  Edad (años)  \
# 0         ARGENTINA             ARG        ADULTO           32
# 1           BELGICA             BEL        ADULTO           34
# 2         VENEZUELA             VEN        ADULTO           31
# 3             SUIZA             CHE        ADULTO           34
# 4            ESPAÑA             ESP        ADULTO           32
# ...             ...             ...           ...          ...
# 229534       CANADA             CAN        ADULTO           35
# 229535    VENEZUELA             VEN        ADULTO           34
# 229536  REINO UNIDO             GBR        ADULTO           37
# 229537       ESPAÑA             ESP        ADULTO           37
# 229538       MEXICO             MEX  ADULTO JOVEN           27
#
#                                    Área Conocimiento         Nivel Académico  \
# 0                        CIENCIAS SOCIALES Y HUMANAS               NO INDICA
# ...

# %%
cols_cat = ['Código ISO país', 'Grupo edad', 'Edad (años)', 'Área Conocimiento', 'Nivel Académico',
       'Estado civil', 'Género', 'Cantidad de personas']

for col in cols_cat:
  print(f'Columna {col}: {df[col].nunique()} subniveles')
# Out:
# Columna Código ISO país: 28 subniveles
# Columna Grupo edad: 2 subniveles
# Columna Edad (años): 16 subniveles
# Columna Área Conocimiento: 14 subniveles
# Columna Nivel Académico: 12 subniveles
# Columna Estado civil: 8 subniveles
# Columna Género: 3 subniveles
# Columna Cantidad de personas: 164 subniveles

# %%
df.describe()
# Out:
#          Edad (años)  Estatura (CM)  Cantidad de personas
# count  229539.000000  229539.000000         229539.000000
# mean       33.354458      76.212988              1.807187
# std         4.328257      83.855153              4.834208
# min        25.000000      -1.000000              1.000000
# 25%        30.000000      -1.000000              1.000000
# 50%        34.000000      -1.000000              1.000000
# 75%        37.000000     165.000000              1.000000
# max        40.000000     715.000000            218.000000

# %%
print(f'Tamaño del set antes de eliminar las filas repetidas: {df.shape}')
df.drop_duplicates(inplace=True)
print(f'Tamaño del set después de eliminar las filas repetidas: {df.shape}')
# Out:
# Tamaño del set antes de eliminar las filas repetidas: (229539, 14)
# Tamaño del set después de eliminar las filas repetidas: (229535, 14)

# %%
df.to_csv('Colombianos en el exterior ETL.csv')
